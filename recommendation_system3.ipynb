# %% [markdown]
# **Import the necessary libraries**

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder, RobustScaler
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

from datetime import datetime
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import confusion_matrix,classification_report,plot_confusion_matrix
from sklearn.metrics import average_precision_score, precision_recall_curve
from sklearn.metrics import auc, plot_precision_recall_curve
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import f1_score

# %% [markdown]
# **Load data into pandas dataframe**

# %%
recom_df = pd.read_csv(r'D:\MACHINE LEARNING\Mentorship program\ML Project2\recom.csv',index_col=0)

# %%
recom_df.head()
# Out:
#     Main_ID Transaction_ID                     Date  Price  Code_Product  \
# 0  90fada91       264f7a69  2022-10-07 20:53:49.153  125.0        5002.0
# 1  9006f9ac       45c7d853  2022-09-17 15:54:57.187   19.0       35012.0
# 2  32270891       61ad76dd  2022-11-28 13:51:55.667  141.0        5005.0
# 3  97e03e47       41ee09f6  2022-09-12 16:20:22.110    4.5       35078.5
# 4  41949228       244fe6d8  2022-10-14 18:53:43.933  129.5       49291.5
#
#    Amount  ItemKey
# 0     1.0   5002.0
# 1     1.0      NaN
# 2     1.0   5005.0
# 3     1.0      NaN
# 4     5.0      NaN

# %%
# To check the dataset for each user(Main_ID) separately
recom_df.sort_values(by='Main_ID')
# Out:
#         Main_ID Transaction_ID                     Date  Price  Code_Product  \
# 31628  00024de6       9016611c  2022-09-03 15:12:52.607    6.0       35097.0
# 37021  00084856       3a8c5a03  2022-10-21 16:40:07.373   24.0       49292.0
# 37004  00084856       cb1b492d  2022-11-05 15:08:11.743   22.0       49291.5
# 18346  0008e848       382c1a6b  2022-09-13 19:34:10.853   13.0       40002.0
# 3927   00096930       3bc7a8f5  2022-11-25 20:13:57.747   48.0       49291.5
# ...         ...            ...                      ...    ...           ...
# 39799  fff905d0       09b9a492  2022-10-17 13:45:20.843   24.0       49292.0
# 13259  fff9726b       de2af9b8  2022-11-10 11:35:57.950   66.0       45001.5
# 38966  fff9726b       4ca53dbb  2022-09-23 15:50:50.903    9.0       30003.0
# 35259  fffa332b       0ff3f909  2022-09-25 11:31:19.700   58.0       49556.0
# 22142  ffff4aa9       6949a057  2022-11-01 14:44:26.533   42.5        5009.0
#
#        Amount  ItemKey
# 31628     2.0      NaN
# 37021     1.0      NaN
# 37004     1.0      NaN
# 18346     1.0      NaN
# 3927      2.0      NaN
# ...       ...      ...
# 39799     1.0      NaN
# 13259     1.0  45001.5
# 38966     1.0  30003.0
# 35259     1.0      NaN
# 22142     1.0   5009.0
#
# [50000 rows x 7 columns]

# %%
recom_df.duplicated().sum()
# Out:
# 171

# %%
recom_df['Transaction_ID'].value_counts()
# Out:
# 9e0891a8    3
# e2fdce56    3
# 78b64973    3
# 4fd75519    3
# e71b5fae    3
#            ..
# 96a11862    1
# adc7d3dc    1
# 9a510f4e    1
# 0f1112fd    1
# 0ff8b41f    1
# Name: Transaction_ID, Length: 48403, dtype: int64

# %%
recom_df[recom_df['Transaction_ID']=='e2fdce56']
# Out:
#         Main_ID Transaction_ID                     Date  Price  Code_Product  \
# 14083  4e1ade63       e2fdce56  2022-10-28 11:58:18.400  531.5        5009.0
# 14586  4e1ade63       e2fdce56  2022-10-28 11:58:18.400  531.5        5009.0
# 26563  4e1ade63       e2fdce56  2022-10-28 11:58:18.400  531.5       10023.0
#
#        Amount  ItemKey
# 14083     1.0   5009.0
# 14586     1.0   5009.0
# 26563     1.0  10023.0

# %%
recom_df.drop_duplicates(inplace=True)

# %%
recom_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 49829 entries, 0 to 49999
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Main_ID         49829 non-null  object
#  1   Transaction_ID  49829 non-null  object
#  2   Date            49829 non-null  object
#  3   Price           49829 non-null  float64
#  4   Code_Product    49829 non-null  float64
#  5   Amount          49829 non-null  float64
#  6   ItemKey         28512 non-null  float64
# dtypes: float64(4), object(3)
# memory usage: 3.0+ MB

# %%
# Since ItemKey and Code_Product columns are same with some of the values are missing in ItemKey. 
# Hence we kept the Code+Product and dropped the ItemKey.
# recom_df['ItemKey'].unique()

# %%
# recom_df['ItemKey1']=recom_df['ItemKey'].fillna(recom_df['Code_Product'])

# %%
# recom_df['ItemKeydiff']=recom_df['ItemKey1']-recom_df['Code_Product']

# %%
# recom_df['ItemKeydiff'].unique()

# %%
recom_df.drop('ItemKey',axis=1,inplace=True)

# %%
recom_df
# Out:
#         Main_ID Transaction_ID                     Date  Price  Code_Product  \
# 0      90fada91       264f7a69  2022-10-07 20:53:49.153  125.0        5002.0
# 1      9006f9ac       45c7d853  2022-09-17 15:54:57.187   19.0       35012.0
# 2      32270891       61ad76dd  2022-11-28 13:51:55.667  141.0        5005.0
# 3      97e03e47       41ee09f6  2022-09-12 16:20:22.110    4.5       35078.5
# 4      41949228       244fe6d8  2022-10-14 18:53:43.933  129.5       49291.5
# ...         ...            ...                      ...    ...           ...
# 49995  bb127ffb       4e0eb5ab  2022-09-24 21:48:20.847  111.5       45004.0
# 49996  a8bc484a       c9946c16  2022-11-18 19:49:01.973   34.0       49292.0
# 49997  c983862a       d1a35c5c  2022-11-24 20:02:43.023  178.0        5001.5
# 49998  8821da12       66f9b474  2022-11-06 13:07:01.423   26.0       49291.5
# 49999  7f281f91       0ff8b41f  2022-10-10 16:06:20.473   52.0       45001.5
#
#        Amount
# 0         1.0
# 1         1.0
# 2         1.0
# 3         1.0
# 4         5.0
# ...       ...
# 49995     4.0
# 49996     1.0
# 49997     1.0
# 49998     1.0
# 49999     1.0
#
# [49829 rows x 6 columns]

# %%
recom_df.sort_values(by='Main_ID',inplace=True)

# %%
recom_df.reset_index(drop=True)
# Out:
#         Main_ID Transaction_ID                     Date  Price  Code_Product  \
# 0      00024de6       9016611c  2022-09-03 15:12:52.607    6.0       35097.0
# 1      00084856       3a8c5a03  2022-10-21 16:40:07.373   24.0       49292.0
# 2      00084856       cb1b492d  2022-11-05 15:08:11.743   22.0       49291.5
# 3      0008e848       382c1a6b  2022-09-13 19:34:10.853   13.0       40002.0
# 4      00096930       3bc7a8f5  2022-11-25 20:13:57.747   48.0       49291.5
# ...         ...            ...                      ...    ...           ...
# 49824  fff905d0       09b9a492  2022-10-17 13:45:20.843   24.0       49292.0
# 49825  fff9726b       de2af9b8  2022-11-10 11:35:57.950   66.0       45001.5
# 49826  fff9726b       4ca53dbb  2022-09-23 15:50:50.903    9.0       30003.0
# 49827  fffa332b       0ff3f909  2022-09-25 11:31:19.700   58.0       49556.0
# 49828  ffff4aa9       6949a057  2022-11-01 14:44:26.533   42.5        5009.0
#
#        Amount
# 0         2.0
# 1         1.0
# 2         1.0
# 3         1.0
# 4         2.0
# ...       ...
# 49824     1.0
# 49825     1.0
# 49826     1.0
# 49827     1.0
# 49828     1.0
#
# [49829 rows x 6 columns]

# %%
# recom_df[recom_df['Code_Product']==5002.5]

# %%
# recom_df.set_index('Main_ID')

# %%
d= pd.pivot_table(index='Main_ID',columns='Code_Product',values='Amount', data=recom_df) 
d
# Out:
# Code_Product  5000.5    5001.0    5001.5    5002.0    5002.5    5003.0    \
# Main_ID
# 00024de6           NaN       NaN       NaN       NaN       NaN       NaN
# 00084856           NaN       NaN       NaN       NaN       NaN       NaN
# 0008e848           NaN       NaN       NaN       NaN       NaN       NaN
# 00096930           NaN       NaN       NaN       NaN       NaN       NaN
# 000c66b7           NaN       NaN       NaN       1.0       NaN       NaN
# ...                ...       ...       ...       ...       ...       ...
# fff8b1c4           NaN       NaN       NaN       NaN       NaN       NaN
# fff905d0           NaN       NaN       NaN       NaN       NaN       NaN
# fff9726b           NaN       NaN       NaN       NaN       NaN       NaN
# fffa332b           NaN       NaN       NaN       NaN       NaN       NaN
# ffff4aa9           NaN       NaN       NaN       NaN       NaN       NaN
#
# Code_Product  5004.0    5004.5    5005.0    5007.0    ...  200035.5  200037.0  \
# Main_ID                                               ...
# 00024de6           NaN       NaN       NaN       NaN  ...       NaN       NaN
# 00084856           NaN       NaN       NaN       NaN  ...       NaN       NaN
# 0008e848           NaN       NaN       NaN       NaN  ...       NaN       NaN
# 00096930           NaN       NaN       NaN       NaN  ...       NaN       NaN
# 000c66b7           NaN       NaN       NaN       NaN  ...       NaN       NaN
# ...                ...       ...       ...       ...  ...       ...       ...
# fff8b1c4           NaN       NaN       NaN       NaN  ...       NaN       NaN
# fff905d0           NaN       NaN       NaN       NaN  ...       NaN       NaN
# fff9726b           NaN       NaN       NaN       NaN  ...       NaN       NaN
# fffa332b           NaN       NaN       NaN       NaN  ...       NaN       NaN
# ffff4aa9           NaN       NaN       NaN       NaN  ...       NaN       NaN
#
# Code_Product  200037.5  200038.0  200038.5  200045.5  200046.0  200046.5  \
# Main_ID
# 00024de6           NaN       NaN       NaN       NaN       NaN       NaN
# 00084856           NaN       NaN       NaN       NaN       NaN       NaN
# 0008e848           NaN       NaN       NaN       NaN       NaN       NaN
# 00096930           NaN       NaN       NaN       NaN       NaN       NaN
# 000c66b7           NaN       NaN       NaN       NaN       NaN       NaN
# ...                ...       ...       ...       ...       ...       ...
# fff8b1c4           NaN       NaN       NaN       NaN       NaN       NaN
# fff905d0           NaN       NaN       NaN       NaN       NaN       NaN
# fff9726b           NaN       NaN       NaN       NaN       NaN       NaN
# fffa332b           NaN       NaN       NaN       NaN       NaN       NaN
# ffff4aa9           NaN       NaN       NaN       NaN       NaN       NaN
#
# Code_Product  200047.0  350027.5
# Main_ID
# 00024de6           NaN       NaN
# 00084856           NaN       NaN
# 0008e848           NaN       NaN
# 00096930           NaN       NaN
# 000c66b7           NaN       NaN
# ...                ...       ...
# fff8b1c4           NaN       NaN
# fff905d0           NaN       NaN
# fff9726b           NaN       NaN
# fffa332b           NaN       NaN
# ffff4aa9           NaN       NaN
#
# [28514 rows x 333 columns]

# %% [markdown]
# **Calculating the pearson correlation**

# %%
d.corr(method='pearson')
# Out:
# Code_Product  5000.5    5001.0    5001.5    5002.0    5002.5    5003.0    \
# Code_Product
# 5000.5        1.000000  0.041565 -0.086369  0.259041       NaN       NaN
# 5001.0        0.041565  1.000000  0.124233 -0.111430       NaN       NaN
# 5001.5       -0.086369  0.124233  1.000000 -0.097222       NaN       NaN
# 5002.0        0.259041 -0.111430 -0.097222  1.000000       NaN       NaN
# 5002.5             NaN       NaN       NaN       NaN       NaN       NaN
# ...                ...       ...       ...       ...       ...       ...
# 200045.5           NaN       NaN       NaN       NaN       NaN       NaN
# 200046.0           NaN       NaN       NaN       NaN       NaN       NaN
# 200046.5           NaN       NaN       NaN       NaN       NaN       NaN
# 200047.0           NaN       NaN       NaN       NaN       NaN       NaN
# 350027.5           NaN       NaN       NaN       NaN       NaN       NaN
#
# Code_Product  5004.0    5004.5    5005.0    5007.0    ...  200035.5  200037.0  \
# Code_Product                                          ...
# 5000.5             NaN -0.161382 -0.076829 -0.292770  ...       NaN       NaN
# 5001.0             NaN -0.301398  0.569109 -0.333333  ...       NaN       NaN
# 5001.5             NaN       NaN       NaN  1.000000  ...       NaN       NaN
# 5002.0             NaN  0.496139       NaN       NaN  ...       NaN       NaN
# 5002.5             NaN       NaN       NaN       NaN  ...       NaN       NaN
# ...                ...       ...       ...       ...  ...       ...       ...
# 200045.5           NaN       NaN       NaN       NaN  ...       NaN       NaN
# 200046.0           NaN       NaN       NaN       NaN  ...       NaN       NaN
# 200046.5           NaN       NaN       NaN       NaN  ...       NaN       NaN
# 200047.0           NaN       NaN       NaN       NaN  ...       NaN       NaN
# 350027.5           NaN       NaN       NaN       NaN  ...       NaN       NaN
#
# Code_Product  200037.5  200038.0  200038.5  200045.5  200046.0  200046.5  \
# Code_Product
# 5000.5             NaN       NaN       NaN       NaN       NaN       NaN
# 5001.0             NaN       NaN       NaN       NaN       NaN       NaN
# 5001.5             NaN       NaN       NaN       NaN       NaN       NaN
# 5002.0             NaN       NaN       NaN       NaN       NaN       NaN
# 5002.5             NaN       NaN       NaN       NaN       NaN       NaN
# ...                ...       ...       ...       ...       ...       ...
# 200045.5           NaN       NaN       NaN       1.0       NaN       NaN
# 200046.0           NaN       NaN       NaN       NaN       NaN       NaN
# 200046.5           NaN       NaN       NaN       NaN       NaN       NaN
# 200047.0           NaN       NaN       NaN       NaN       NaN       NaN
# 350027.5           NaN       NaN       NaN       NaN       NaN       NaN
#
# Code_Product  200047.0  350027.5
# Code_Product
# 5000.5             NaN       NaN
# 5001.0             NaN       NaN
# 5001.5             NaN       NaN
# 5002.0             NaN       NaN
# 5002.5             NaN       NaN
# ...                ...       ...
# 200045.5           NaN       NaN
# 200046.0           NaN       NaN
# 200046.5           NaN       NaN
# 200047.0           NaN       NaN
# 350027.5           NaN       NaN
#
# [333 rows x 333 columns]

# %%
#A list of 20 products to recommend to a user who has purchased'5002.0'
# d.corr(method='pearson')[5002.0].sort_values(ascending=False).iloc[:20]

# %% [markdown]
# **We have to recommend multiple items for each user**<br>A list is created containing users and the items purchased by the user

# %%
# lst1 = list(zip(recom_df['Main_ID'], recom_df['Code_Product']))
lst=list(set(list(zip(recom_df['Main_ID'], recom_df['Code_Product']))))
# lst

# %% [markdown]
# **Converting the list into dictionary containing multiple items purchased by each user**

# %%
Code_Product_dict = dict()

for line in lst:
    if line[0] in Code_Product_dict:
        # append the new number to the existing array at this slot
        Code_Product_dict[line[0]].append(line[1])
    else:
        # create a new array in this slot
        Code_Product_dict[line[0]] = [line[1]]

# %%
Code_Product_dict
# Out:
# {'f3d03d7a': [5000.5, 30026.5, 48556.5, 25003.0, 5011.5],
#  '34d5fd08': [49292.0, 10023.0],
#  'e2637be7': [10023.0, 10015.0],
#  'c7e95da6': [45004.0, 5009.0, 5002.0, 49427.5],
#  '29a921bc': [5025.0],
#  'ea785e04': [35005.0, 5000.5, 49129.0],
#  '89726537': [10015.0, 45003.5, 30008.0, 45000.5, 45004.0],
#  'a180aff9': [35000.5],
#  '9a2886b4': [25003.0],
#  'db555906': [10032.5],
#  'c0f5501d': [49291.5, 45001.5],
#  '310fc119': [49291.5, 5000.5],
#  'ea248aa6': [40028.5],
#  'ec55ffc8': [40009.5, 10004.0, 40020.5, 45001.0, 5001.0, 10023.0],
#  'e709f216': [5027.5,
#   5011.5,
#   45000.5,
#   45004.0,
#   48513.0,
#   10022.5,
#   49291.5,
#   35001.0],
#  '0032f70b': [5009.0],
#  '6827331a': [48504.5, 5011.5, 45004.0, 49291.5, 35078.5],
#  '8bfeeb44': [10004.0, 45004.0, 49556.0, 49292.0],
#  '9be83098': [5000.5, 5025.0],
#  '180e5ee3': [49291.5],
#  'f404d05d': [10004.0],
#  '3392c111': [5000.5, 49356.0, 5009.0, 5013.0],
#  '74790659': [49291.5],
#  '856e70a6': [45001.0, 5009.0, 35000.5, 30003.5, 40019.0],
#  '7cf424e6': [40002.0, 40028.5, 49129.5],
#  '03ebf400': [35006.0, 35078.5],
#  'a139c2a8': [49292.0],
#  '7585f76c': [5027.0,
#   25003.5,
#   5011.5,
#   45004.0,
#   48513.0,
#   5012.5,
#   10013.0,
#   45001.5,
#   5013.0,
#   35020.5,
#   30027.0],
#  '1c2cd619': [45004.0, 49291.5],
#  '926d9da6': [45001.0],
#  'd29b2550': [10015.0, 45001.5],
#  'fb4b409b': [49291.5],
#  '2052e595': [15003.0, 30003.0, 35013.5, 20007.5],
#  '3855b28b': [49292.0, 35075.5, 35096.5],
#  'fb2d8bdb': [5009.0],
#  '81f9ceb1': [49427.5,
#   45004.0,
#   5012.0,
#   5000.5,
#   40069.5,
#   49291.5,
#   40009.5,
#   49292.0,
#   5002.0,
#   10003.0],
#  'be6e0d29': [35071.5,
#   45004.5,
#   45004.0,
#   35075.5,
#   35079.5,
#   10013.0,
#   49356.0,
#   5017.0,
#   49291.5,
#   5009.0,
#   30027.0,
#   49556.0,
#   49292.0,
#   10023.5,
#   40030.0,
#   35005.5],
#  'a33a57f9': [5000.5, 5013.0, 49556.0, 49427.5, 48513.0, 45000.5],
#  '79ff3b6b': [5000.5],
#  'b372d2a1': [48504.5,
#   48513.0,
#   45004.0,
#   45004.5,
#   30014.0,
#   45001.0,
#   40045.0,
#   45002.5,
#   49292.0,
#   49427.5],
#  '6217c356': [35001.0],
#  'db1a6776': [49556.0],
#  '423f5374': [49291.5],
#  'de803552': [45001.0],
#  '75bdc2b4': [30027.0],
#  'b7129f7a': [49356.0],
#  'ad92e92f': [49356.0, 5000.5],
#  '77d67088': [45004.0],
#  'eec8ea28': [5023.0,
#   5027.0,
#   30029.5,
#   45004.0,
#   35075.5,
#   49291.5,
#   40029.0,
#   30027.0,
#   49292.0,
#   15016.5,
#   10023.0,
#   5002.0,
#   10024.0],
#  'f1cea5db': [5025.0,
#   5009.0,
#   49556.0,
#   49292.0,
#   10024.0,
#   48513.0,
#   10013.0,
#   5000.5,
#   10022.5,
#   49356.0,
#   49291.5],
#  'e7b2aab4': [35000.5, 10015.0, 40036.0, 40009.5],
#  'cad7e297': [5000.5, 5002.0, 40002.0],
#  '754724ae': [5000.5],
#  'fd901dad': [49292.0, 45004.0, 45004.5, 48513.0, 49556.0],
#  '922c0e2a': [48504.5],
#  '0409d77e': [5005.0,
#   49292.0,
#   25003.0,
#   45004.0,
#   10013.0,
#   5000.5,
#   45001.0,
#   49291.5],
#  '8fc13de4': [49292.0],
#  '66da73f0': [40027.0, 30009.5, 30014.0, 30003.0],
#  'cb8a8f17': [5000.5,
#   45001.5,
#   45001.0,
#   49291.5,
#   35000.5,
#   49556.0,
#   10015.0,
#   49292.0,
#   45003.0,
#   5027.0,
#   5027.5,
#   25003.0,
#   10000.5,
#   5011.5,
#   48513.0,
#   45000.5,
#   45004.0],
#  'f3140e3b': [35000.5,
#   10003.0,
#   49427.5,
#   30021.5,
#   10033.0,
#   48513.0,
#   5012.0,
#   5000.5,
#   30014.5,
#   5001.5,
#   5001.0,
#   15016.5,
#   10023.5],
#  'ba9dba97': [45002.5],
#  '6a7fe46b': [48513.0],
#  '1fb6aab3': [48513.0, 30021.5, 45001.5, 5017.0, 49291.5, 5009.0, 25003.0],
#  '297b43a4': [45004.0,
#   35075.5,
#   35079.5,
#   5000.5,
#   35096.5,
#   49291.5,
#   49556.0,
#   35000.5,
#   49292.0,
#   25003.5,
#   25003.0],
#  '2267f86a': [25003.0],
#  'ee5b92c7': [49291.5, 45002.5],
#  '9613dabb': [45003.0, 5012.0, 49291.5],
#  '39e158af': [45001.0],
#  'a7393b30': [49292.0, 45002.5, 10023.0],
#  '93a72cad': [5000.5],
#  '72cbfdf3': [49291.5],
#  'e3a5269a': [48504.5],
#  '40d2d9f8': [30009.5],
#  '8d7d80fe': [49291.5],
#  'd08ef182': [40021.5,
#   48556.5,
#   49292.0,
#   25003.5,
#   5011.5,
#   45004.0,
#   45004.5,
#   48513.0,
#   5000.5,
#   5009.0],
#  '4c521c08': [45001.0, 5009.0, 10023.0],
#  '9e8d13d7': [49291.5],
#  'b3745fb1': [35004.5],
#  'bbdecd18': [5009.0],
#  'd853c12f': [10033.0],
#  'd7555a6f': [40009.5],
#  '46277c41': [49129.0, 49130.0, 35005.0, 35006.0, 49291.5],
#  '73a8a453': [40021.5],
#  '6dcec086': [25003.5],
#  'c16de668': [49356.0, 45004.0],
#  '38b56945': [5001.0],
#  'f29fde63': [48504.5],
#  'c2afcc39': [45004.0,
#   25004.5,
#   5000.5,
#   45001.5,
#   49291.5,
#   5001.5,
#   5001.0,
#   45002.5,
#   30003.0,
#   48556.5,
#   49292.0,
#   10003.0,
#   5027.0,
#   10032.5],
#  '4a07f9bf': [49556.0, 49292.0, 45000.5, 30027.0],
#  'a7b21a6e': [10024.0, 5000.5, 5004.5, 5012.0, 45001.0, 15016.0],
#  '8f8ea7bc': [5009.0],
#  '91aa67e9': [5027.0],
#  '969cc070': [40009.5],
#  'e5601c77': [45004.0],
#  'cce99d0a': [25003.0, 10024.0, 5012.0, 5000.5, 10015.0, 5002.0],
#  '115871a5': [48513.0, 30014.5],
#  '82317108': [48523.5, 35096.5],
#  '42860c76': [5000.5, 49292.0],
#  '2b39d301': [5017.0, 5011.5],
#  '008c1c62': [48513.0, 5009.0, 35001.0],
#  '2fd872a0': [48504.5, 5000.5, 5001.0],
#  '74249414': [48589.0, 30009.0, 30009.5],
#  'de19b47a': [10013.0, 49356.0, 30003.0, 49292.0, 35078.5],
#  'b6ccae48': [45004.0],
#  '226bb6a8': [35007.5,
#   49291.5,
#   5001.0,
#   49556.0,
#   10003.0,
#   5002.0,
#   35078.5,
#   35005.5,
#   49427.5,
#   5027.5,
#   35006.0,
#   48513.0,
#   45004.0,
#   45001.0,
#   5000.5],
#  '202c2f81': [45000.5],
#  '9d1d5976': [49291.5],
#  '1ec06219': [10033.0],
#  '51d2ad7b': [48504.5,
#   10004.0,
#   5011.5,
#   10013.0,
#   45001.5,
#   49567.5,
#   49291.5,
#   5009.0,
#   49292.0,
#   40002.0],
#  '438658c7': [25003.5],
#  '803cf112': [5011.5, 49292.0],
#  '99d6a85b': [49356.0],
#  '3134b3d8': [35092.5, 40019.5],
#  'a4aac35f': [35096.5, 35076.0, 5001.5, 5011.5, 5000.5],
#  '1726ef6f': [49130.0],
#  '128517ca': [45002.5, 35000.5, 40036.0, 5012.0],
#  'a6a14291': [5002.0,
#   45003.5,
#   5011.5,
#   10013.0,
#   5000.5,
#   5025.0,
#   5009.0,
#   5001.0,
#   5005.0,
#   40017.5,
#   10015.5,
#   10015.0],
#  '00d8d615': [10013.0, 5000.5, 5025.0, 49483.0, 10015.0],
#  'ed74fe5a': [35076.0,
#   49291.5,
#   49292.0,
#   49427.5,
#   5027.0,
#   5011.5,
#   30021.5,
#   45004.0,
#   5000.5],
#  'f232dc02': [25003.5, 45004.0, 5000.5, 35097.0, 30027.0, 15016.0, 5002.0],
#  '564f4663': [48513.0],
#  '09f58a61': [5009.0, 35078.5],
#  'd7603f1a': [5011.5,
#   45004.0,
#   48513.0,
#   10013.0,
#   5009.0,
#   5001.5,
#   30027.0,
#   10023.5,
#   10015.0,
#   49292.0,
#   25003.5,
#   25003.0],
#  'e9f3750d': [5001.0],
#  'fe4f0d81': [5009.0],
#  '314f0a9a': [5025.0, 5000.5],
#  'c19e4dc1': [35075.5],
#  'e1d976d8': [30003.5,
#   48556.5,
#   49292.0,
#   10032.5,
#   35104.0,
#   10013.0,
#   5000.5,
#   35096.5,
#   45002.5,
#   30027.0],
#  '305690b1': [30027.0],
#  'e5cb61de': [40043.0, 30014.5, 45003.5],
#  '21bfb3a6': [15004.5, 5002.0, 45001.0, 10023.5],
#  'eeb41980': [49291.5],
#  '1958556a': [10003.0],
#  '4377bf45': [49292.0],
#  'e34e3f91': [49292.0, 45000.5, 5000.5, 45001.0],
#  '13672c7b': [5000.5, 45004.0, 5012.0],
#  '83812e4d': [5000.5],
#  '72c0d4ca': [48556.5],
#  '233046eb': [49556.0, 5011.5],
#  '6a1fb990': [5011.5],
#  'dc308699': [49292.0, 49291.5],
#  '27aa514e': [48589.0,
#   5007.0,
#   30021.5,
#   10013.0,
#   5000.5,
#   49567.5,
#   30002.0,
#   5009.0,
#   40021.5,
#   10023.0,
#   35000.5,
#   40030.5],
#  '2224ff93': [49291.5],
#  'e957a067': [45003.0, 48504.5, 45001.0, 10022.5, 49356.0],
#  '24b17104': [45001.0,
#   15003.0,
#   49291.5,
#   35000.5,
#   49556.0,
#   49292.0,
#   10003.0,
#   10024.0,
#   5027.0,
#   45004.0,
#   40036.0,
#   10013.0],
#  '0d806656': [20024.0],
#  '35e1f645': [5001.0],
#  '84289a9d': [49292.0],
#  '36bd166c': [5004.5,
#   45013.5,
#   45001.5,
#   45001.0,
#   5000.5,
#   15015.5,
#   10022.5,
#   49291.5,
#   30027.0,
#   5009.0,
#   10031.0,
#   5002.0,
#   25003.0],
#  '5aceeb37': [49291.5],
#  '7d0fb553': [40019.0],
#  '7350fabb': [49291.5, 10015.0, 5000.5, 49356.0],
#  'f7941ae4': [5000.5, 45004.0],
#  'a67a1cc4': [5011.5, 25003.0],
#  '9b2e9e44': [30014.0],
#  '515b9e02': [48513.0, 49356.0, 40002.5, 45004.0, 40019.0],
#  'b707af66': [49356.0, 49292.0],
#  'f9ff36d9': [5000.5, 49291.5, 40009.5, 49292.0, 35005.5],
#  '427c7f56': [49292.0],
#  '61614cdd': [5000.5],
#  '72472a24': [49292.0, 10003.0, 15006.0, 10013.0, 5025.0, 10023.5],
#  '83ba8f03': [30027.0,
#   49556.0,
#   49292.0,
#   40030.0,
#   35005.5,
#   45004.0,
#   5000.5,
#   49291.5,
#   5009.0],
#  'f15c38df': [40021.5],
#  'ec7352ca': [30014.5, 200005.0],
#  '6b30b794': [49356.0],
#  'ce5a0b67': [5009.0],
#  '99f3287f': [45004.0],
#  '3a1aeeac': [35089.0],
#  '8baf10cd': [49427.5],
#  'edc9fb56': [10004.0],
#  'cd56ed65': [40021.5, 45002.5, 15008.5, 49292.0, 35079.0, 10013.0, 45001.0],
#  '3bb66630': [35075.5, 35076.0, 10023.0],
#  'e2a6a10f': [49292.0, 45004.0, 5000.5, 49567.5, 49356.0, 49291.5],
#  '21e2aea9': [49291.5, 48504.5, 45004.0],
#  '7d5d5038': [45004.0],
#  'bc179202': [49427.5, 45004.0, 5000.5, 10023.0, 5002.0],
#  '31de7981': [40009.5],
#  '0cc0e09d': [48513.0,
#   49567.5,
#   49291.5,
#   5009.0,
#   10032.5,
#   25003.0,
#   5011.5,
#   45004.0],
#  'e09040ed': [49291.5, 10023.0, 25003.5, 5011.5, 45004.5, 5000.5],
#  '5a503765': [35000.5],
#  '38364a2b': [45002.5, 200016.0, 200046.0, 10032.5, 45001.0],
#  '3d647e52': [15005.0],
#  'ecf9fdee': [5027.0],
#  '7b15b443': [49556.0, 15016.0, 5002.0, 45004.0, 49291.5],
#  'fd11ca32': [5012.0,
#   5000.5,
#   35076.0,
#   5001.5,
#   5001.0,
#   5009.0,
#   35000.5,
#   35106.5,
#   45003.0,
#   10032.5,
#   25003.0,
#   5011.5,
#   10000.5,
#   48513.0,
#   45000.5,
#   45004.0],
#  '7333a803': [45001.5,
#   5025.0,
#   40021.5,
#   49556.0,
#   40002.0,
#   10032.5,
#   49427.5,
#   25003.5,
#   10004.0,
#   40019.0,
#   45004.0,
#   5012.0],
#  '7d77690d': [5009.0],
#  '309666ec': [10024.0, 25003.0, 45004.0, 5012.0],
#  'c4f50f65': [49291.5],
#  'f7a64920': [49292.0],
#  '4c71a152': [10015.0, 49292.0],
#  'bfdda82d': [35076.0],
#  'c020112a': [5027.0, 10013.0, 5000.5],
#  '23a528e8': [45000.5, 40021.5, 45003.5],
#  'c916f4c4': [30021.5, 45004.0],
#  'dcf1944e': [5011.5],
#  '81fde20e': [45001.0, 5000.5],
#  '3501f50c': [49292.0],
#  '0ebc56cb': [5001.5, 5000.5, 5009.0],
#  '24a05e61': [25003.0, 45001.0],
#  'f2c2188c': [5000.5],
#  '4ef83d30': [45002.5],
#  '591a3ce4': [45002.5,
#   10015.0,
#   15016.0,
#   10003.0,
#   5002.0,
#   45004.5,
#   45001.0,
#   5000.5,
#   30014.5,
#   10022.5,
#   5001.0],
#  'b40ab754': [10004.0, 45001.5],
#  '82c2b6cf': [5004.5],
#  '5519c797': [5027.0],
#  '4b9970f7': [35006.5],
#  'de377510': [40045.5, 40009.5, 25003.0, 40027.5, 45004.0, 45001.5, 49291.5],
#  '770663e6': [10013.0],
#  '06dd84fe': [40028.5],
#  'c9559454': [49427.5, 5000.5],
#  'd13dbbdf': [5000.5, 45004.0],
#  '79dfdd28': [49567.5],
#  'c83c2295': [35096.5],
#  '622e719f': [49292.0],
#  'af6c53a4': [35106.0],
#  '7244b2c1': [10015.0, 25003.0, 35042.0, 45004.0, 5000.5, 5001.0, 5009.0],
#  'bb611525': [45000.5],
#  '6f6f19bf': [49291.5],
#  '4b30b669': [49291.5, 40021.5, 35078.5, 35018.5],
#  'd1723637': [10013.0, 30008.0],
#  '9a7f1a3f': [40009.5, 5000.5, 45001.5, 45001.0, 49291.5],
#  '7dffbccb': [5017.0],
#  'fcece86e': [35000.5, 40021.5],
#  '80e28d65': [49292.0],
#  '5a9210ed': [45004.0],
#  '98ac7996': [40045.5],
#  'd8dd0213': [49129.0],
#  '4c43a840': [10013.0],
#  'dff9f011': [25003.0],
#  '16de7753': [15020.5],
#  'ed0f1257': [45002.5],
#  '8286fffa': [35076.0, 49291.5, 45003.0, 5002.0, 35078.0],
#  'f1ded414': [25003.0],
#  'def67083': [35096.5, 49292.0, 40002.0, 25003.0],
#  '44f542a3': [49291.5],
#  '7e631993': [45004.0],
#  '2e7c7c29': [30027.0,
#   30003.0,
#   25003.0,
#   25003.5,
#   10024.0,
#   40027.0,
#   45004.0,
#   40028.0,
#   45001.0,
#   5000.5,
#   30014.5,
#   49291.5,
#   5025.0],
#  '6423aae6': [5002.0, 49556.0],
#  'ce13d787': [45000.5],
#  'f637d090': [49567.5],
#  '23892359': [40030.0],
#  '099fef0b': [49292.0, 40045.5],
#  'cd134d88': [30003.5],
#  '849ccdd3': [40029.0],
#  'b2c4a0a6': [35005.0, 35096.5],
#  '507137e2': [49291.5],
#  'fa1baaa7': [48523.5],
#  '86c41f16': [45004.0],
#  '379e60c5': [5002.0],
#  '280c692f': [45004.0],
#  '423d86af': [49291.5],
#  'd7629220': [10013.0],
#  '2813f515': [35088.0, 5009.0],
#  'bb440034': [40028.5],
#  '82d79561': [49291.5, 5000.5],
#  '9ad097b7': [10013.0],
#  '274ef372': [49291.5,
#   5001.5,
#   40009.5,
#   10015.0,
#   48504.5,
#   25003.0,
#   5011.5,
#   45004.0,
#   48513.0,
#   5000.5,
#   49356.0],
#  'b2510cf9': [10000.5, 48504.5],
#  'c9a5616e': [25003.0, 30002.0, 49291.5],
#  '90b4dc2c': [15016.0, 10032.5, 35005.5, 25003.5, 15008.5],
#  '0d4a1f86': [5009.0],
#  '6ba1fc06': [5012.0, 35076.0, 49556.0, 49292.0, 10023.0, 25003.0],
#  'f41ef186': [15005.0],
#  'b559f2ce': [45002.5, 49292.0],
#  '92b57689': [49291.5],
#  '3fe16bf0': [35097.0],
#  'f8fbce82': [5000.5],
#  'fb8d90a7': [5009.0,
#   49129.5,
#   49556.0,
#   49292.0,
#   10023.0,
#   25003.0,
#   48504.5,
#   49291.5],
#  '21e60517': [49292.0, 10023.0, 35013.5, 5027.5, 5000.5, 49291.5, 5009.0],
#  'ac9de42f': [49291.5, 49356.0, 5002.0],
#  'd7f63b03': [40028.5],
#  '2544b6ad': [49129.5],
#  'b42b58c4': [40072.5],
#  '5ef2e195': [35096.5, 35076.0],
#  '4fe751a1': [49291.5, 5000.5],
#  '4d020223': [5000.5, 45001.0, 48556.5, 45004.0],
#  '46f203af': [49292.0],
#  '2a876f8a': [25003.5, 5011.5, 45000.5, 49291.5, 15016.5, 35106.0, 49292.0],
#  'd07b87a0': [45004.0],
#  '15c427cc': [5001.5, 35000.5, 49292.0, 35076.0],
#  'c3d8d4f8': [10013.0],
#  '5f68c556': [49291.5],
#  'a6062872': [49292.0, 40072.5],
#  'e74b72d4': [10013.0, 49292.0],
#  'f41b0c44': [45001.0, 5009.0],
#  '2412e24f': [5011.5],
#  'd15c47b2': [5000.5,
#   30014.0,
#   5017.0,
#   49291.5,
#   30027.0,
#   49556.0,
#   49292.0,
#   40043.0,
#   30021.5,
#   5012.0,
#   10013.0],
#  '4004b456': [49291.5, 49292.0],
#  '455e1130': [35000.5],
#  '707339ef': [10032.5, 35005.5, 49292.0],
#  'ec975630': [45004.0],
#  '4cb0f8fa': [49291.5, 45004.0],
#  '5a08f5ce': [5000.5, 25003.0],
#  'c1e20ae9': [45001.5, 49292.0],
#  '21829a01': [40029.0],
#  'be41e79b': [49291.5],
#  '268cafa4': [49291.5],
#  'a193d604': [49291.5, 35004.5, 15004.0, 45004.0],
#  '4b9b80e2': [49292.0],
#  '27e51f8a': [5002.0,
#   35001.0,
#   25003.5,
#   40043.0,
#   40047.0,
#   45004.0,
#   35096.5,
#   5012.0,
#   45001.0,
#   35076.0,
#   35077.0,
#   5009.0,
#   35000.5,
#   49292.0,
#   35106.0,
#   48589.0],
#  '60eb798a': [40019.0, 10003.0],
#  '7aa7d49a': [49292.0,
#   35005.5,
#   25003.5,
#   5011.5,
#   45004.0,
#   30009.0,
#   10013.0,
#   40028.5,
#   5000.5,
#   5025.0,
#   49291.5,
#   10023.5],
#  '86c89fd0': [49567.5,
#   40017.5,
#   40021.5,
#   30027.0,
#   49292.0,
#   48556.5,
#   5023.0,
#   5011.5,
#   45004.0],
#  '44a71739': [49292.0],
#  'f907b145': [45004.0],
#  'b4ceae5e': [48522.5, 49292.0, 48589.0, 48504.5],
#  '38821df9': [5000.5],
#  'de824e70': [20005.5,
#   15004.5,
#   5002.0,
#   45004.0,
#   35002.5,
#   10013.0,
#   40020.5,
#   49291.5,
#   5025.0,
#   10015.0,
#   49292.0],
#  '099260f5': [160009.5],
#  '7610e855': [5000.5],
#  '9175cd25': [30021.5, 5000.5],
#  '72bddc16': [49292.0, 5011.5, 5001.5],
#  'e14e51fd': [15015.5, 48556.5, 15002.0],
#  '1633b031': [10003.0, 35096.5, 49291.5, 35077.0],
#  '3a25cdff': [30002.0, 5025.0],
#  '89273b74': [49291.5, 45001.0],
#  'f41bbcc7': [49291.5, 40001.5, 40019.0],
#  'd70eca81': [10013.0, 5000.5],
#  'dcdadfef': [10000.5],
#  'bda8c5ad': [48504.5, 45004.0, 5000.5, 49291.5, 35000.5],
#  '8a88b6c5': [15016.5, 49291.5],
#  '769e3f53': [49292.0],
#  'c087900b': [49556.0, 5011.5],
#  '83bb7b79': [49556.0,
#   49292.0,
#   10003.0,
#   35005.5,
#   48504.5,
#   45004.0,
#   10001.0,
#   5012.0,
#   5000.5,
#   49291.5,
#   40009.5],
#  '01b7de80': [35077.0, 45004.0, 10022.5],
#  '9f9c2c62': [30002.0,
#   5017.0,
#   35089.0,
#   5001.0,
#   40054.0,
#   10023.0,
#   10015.0,
#   10003.0,
#   10024.0,
#   10004.0,
#   5011.5,
#   45004.0,
#   10013.0,
#   35092.0,
#   5000.5],
#  '54698ccb': [35005.5, 49292.0],
#  '49cc4071': [30003.5,
#   49292.0,
#   25003.5,
#   10004.0,
#   48513.0,
#   45000.5,
#   30021.5,
#   45004.0,
#   10013.0,
#   45001.5,
#   5000.5,
#   30014.5,
#   5009.0,
#   49556.0],
#  'be10b6a0': [49292.0, 40030.5, 25003.5, 45004.0, 49567.5, 48556.5],
#  'b11699ac': [49292.0,
#   25003.0,
#   10000.5,
#   45004.0,
#   5000.5,
#   5001.0,
#   5009.0,
#   10023.5],
#  '73d0a224': [5000.5],
#  '17fc5d1e': [49356.0],
#  '3a2ace65': [35005.5, 35006.5],
#  'e883b0d9': [5017.0, 10023.5, 10003.0, 10024.0],
#  '6c3dbf2b': [49427.5],
#  'b7578e0c': [5025.0],
#  'f18da76f': [49292.0],
#  '671dbd79': [5009.0, 45002.5, 49292.0, 5000.5],
#  '1b2d776f': [15004.0],
#  'ee829c51': [48504.5],
#  '06bfa3f3': [25003.0, 45004.0, 5009.0],
#  '3923398b': [5001.5],
#  '612f55a1': [30003.5],
#  '5ec678a3': [49567.5],
#  '6fd83785': [45001.5],
#  'c045b7f5': [5000.5],
#  '16eb65c1': [35076.0, 5004.5],
#  'f9acf8ab': [15004.5, 45003.5, 25003.5, 45004.0, 5000.5, 45001.0],
#  'bbec4548': [5002.0],
#  '2770a85d': [5000.5, 49292.0, 10023.5, 35005.0],
#  '27424db3': [30009.0],
#  '2eae5cbe': [30014.5, 5000.5],
#  '37fed321': [40019.0,
#   45000.5,
#   10013.0,
#   5000.5,
#   35076.0,
#   49291.5,
#   10022.5,
#   40029.0,
#   40046.0,
#   49292.0,
#   35005.0,
#   5023.0,
#   5011.5,
#   45004.0],
#  '595a5a28': [49291.5],
#  '32499d98': [49292.0],
#  'a4b84fec': [5000.5],
#  'c872b0b7': [48556.5],
#  'ca987f34': [49356.0],
#  '4cf75875': [10015.0, 10032.5, 5012.5, 5000.5, 30027.0],
#  '98cca486': [10004.0, 49356.0, 49291.5],
#  'fe4c9022': [49291.5, 48513.0],
#  '8286d528': [45001.5],
#  'e19f0bcb': [35000.5,
#   40030.0,
#   49292.0,
#   25003.0,
#   45004.0,
#   10013.0,
#   45001.5,
#   5000.5,
#   10022.5,
#   10023.0],
#  '5be9e3db': [49129.0, 49265.5],
#  'dfad0d5b': [48513.0],
#  '0a1134a5': [15002.0, 5000.5, 25003.5],
#  'ea6cbfde': [48504.5],
#  '3d4bfd81': [45001.5,
#   10022.5,
#   5009.0,
#   5001.0,
#   10023.0,
#   10015.0,
#   48513.0,
#   10013.0,
#   5000.5],
#  'aa2c7eb7': [49291.5, 48504.5],
#  '0616e26a': [49292.0],
#  'ba193154': [10013.0],
#  'e9c6b0b6': [45004.0, 5001.0, 25003.0],
#  'd6495bc9': [5000.5, 10015.0],
#  'a0cf7ca0': [5011.5],
#  '223180d2': [40021.5],
#  '6ad1956e': [49291.5, 48513.0],
#  '55ffebc8': [49291.5],
#  'de0b3bdc': [49427.5],
#  '7764dd60': [10032.5, 5000.5, 40036.0, 49291.5, 35004.5],
#  '43ab082f': [49315.0],
#  '2ac3fd10': [49291.5, 49292.0, 5000.5],
#  '0227ea3a': [49291.5],
#  '867eeba8': [35001.0, 5017.5],
#  'c8372807': [49265.5, 45004.0, 49292.0],
#  '6372fe78': [45001.0, 40030.5, 40030.0, 35005.0, 25003.5],
#  '47ef886e': [40030.0, 5003.0, 45013.5, 5001.5, 49292.0],
#  '1d64c93a': [40029.0],
#  'f1b8c7ae': [40036.0],
#  'f3bbe942': [5000.5],
#  '72256780': [5000.5],
#  '42b903a5': [49292.0],
#  'b350bb71': [5000.5,
#   45001.0,
#   49291.5,
#   5009.0,
#   35000.5,
#   10032.5,
#   25003.0,
#   48513.0],
#  'f76fa927': [5000.5, 10024.0, 5011.5],
#  '8644b9a3': [35077.0, 10023.0, 25003.0, 35076.0, 5009.0],
#  '82358b3b': [49291.5, 35000.5, 35078.5, 49427.5, 25003.0, 45004.0],
#  'a0759c8a': [49291.5],
#  '3cba6652': [49292.0],
#  '2827bf8e': [25003.5,
#   5007.0,
#   45004.0,
#   35076.0,
#   45001.5,
#   49356.0,
#   5009.0,
#   35000.5,
#   10015.0],
#  'f63e6b49': [10022.5, 45004.0],
#  '6db34e23': [200022.0],
#  '309e0f92': [49292.0],
#  '77bf625c': [49292.0],
#  '7fd1390c': [45002.5,
#   5001.0,
#   49556.0,
#   35000.5,
#   10015.0,
#   10003.0,
#   25003.0,
#   5000.5,
#   5012.0,
#   45001.5,
#   10022.5,
#   5009.0],
#  '47ca3b5f': [49291.5,
#   49556.0,
#   35000.5,
#   49292.0,
#   10003.0,
#   48504.5,
#   40019.0,
#   45001.0,
#   5000.5,
#   49567.5],
#  'fcd76b89': [10004.0,
#   45004.0,
#   48513.0,
#   5000.5,
#   40020.5,
#   45001.0,
#   49567.5,
#   49291.5,
#   5001.0,
#   49292.0,
#   5002.0,
#   49427.5,
#   5023.0,
#   25003.0,
#   25003.5,
#   10000.5],
#  '1cfbe316': [45001.5, 49356.0, 49291.5, 49292.0, 5011.5, 10013.0],
#  'f0e787e2': [49130.0, 30008.0, 35005.5, 45013.5, 49129.5],
#  'bb3c0a55': [5000.5, 5001.5, 10023.0, 49130.0],
#  'c3e426c3': [5009.0],
#  '79a21ec3': [49265.5],
#  '5a2d68cc': [45004.0, 5009.0, 10004.0],
#  '3a37b4bd': [5009.0],
#  'd7f9e682': [45003.0,
#   35001.0,
#   45004.0,
#   35018.0,
#   35075.0,
#   10013.0,
#   35011.0,
#   5025.0,
#   5017.0,
#   15016.0],
#  '4ed202fc': [49556.0],
#  '5ce8da2c': [35096.5, 49291.5, 35097.0],
#  'b864e87c': [49292.0],
#  '610dc804': [5027.0],
#  'c49861b1': [48556.5],
#  'e3acd47f': [40046.5, 40069.5, 45002.5, 35000.5],
#  'a0cb2ab4': [49129.0],
#  '28035642': [35078.5, 10013.0, 5009.0],
#  '42f739b6': [5000.5],
#  'b27e0a2c': [45001.0],
#  'a1f92a57': [25003.0],
#  '8b814ac8': [10015.0],
#  'd1ee2e80': [49292.0],
#  '8d8a874e': [10024.0],
#  'e29692ff': [10023.0, 30002.0],
#  '2156239c': [45001.0],
#  '75c3b46c': [35096.5],
#  '64bf4ace': [10032.5, 15005.0, 45004.0, 5000.5],
#  '49affd49': [35019.5, 35076.0, 49291.5, 5001.5, 10004.0, 5000.5],
#  'bb6a717c': [10015.5,
#   49292.0,
#   10013.0,
#   5000.5,
#   49291.5,
#   10022.5,
#   15003.0,
#   45002.5],
#  '9ffc890e': [45004.0],
#  '1aba9250': [10013.0],
#  'ef8f795d': [25003.0],
#  '7054a8a8': [49292.0],
#  '7eb33a8c': [40017.5],
#  'b0270bf9': [25003.0,
#   10004.0,
#   40019.5,
#   45004.0,
#   5012.0,
#   10013.0,
#   30014.5,
#   49291.5,
#   45002.5,
#   48556.5,
#   40002.5],
#  '00d9cbc6': [10013.0],
#  '58976548': [5000.5],
#  'a2c7995d': [5000.5, 49356.0, 49291.5, 48556.5, 35018.0],
#  '1e2861f4': [45001.0, 10023.0, 45000.5, 10001.5],
#  '28f03c0b': [49129.0],
#  'f0a64acc': [49292.0],
#  'f5c14b3f': [49556.0, 5000.5],
#  '86852f1e': [10023.0, 45004.0, 5025.0],
#  '733507ca': [5011.5],
#  'd36e2edf': [45004.0, 10013.0],
#  'c0c51ed6': [10013.0, 10003.0, 25003.0, 10004.0],
#  '68ab613f': [45004.0, 45001.0, 30027.0, 49292.0],
#  '3680b56b': [45000.5, 48513.0, 5012.0, 10022.5, 5001.0, 10015.5, 10032.5],
#  'dda528d8': [10030.5,
#   30002.0,
#   5017.0,
#   49292.0,
#   10032.5,
#   48513.0,
#   45004.0,
#   35075.5,
#   10013.0,
#   5000.5],
#  '7e1238de': [40030.0,
#   45003.5,
#   48513.0,
#   20011.0,
#   5000.5,
#   40069.5,
#   49356.0,
#   49291.5],
#  'c9bbd8f8': [10013.0,
#   5000.5,
#   49291.5,
#   40009.5,
#   48523.5,
#   49292.0,
#   10024.0,
#   48504.5,
#   45004.0],
#  '71820198': [45004.0],
#  'e870b655': [35080.0, 49292.0, 49414.0, 35076.0],
#  '8bfd7025': [49291.5, 5001.5, 200022.0, 45004.0, 5000.5],
#  '18fe71d7': [5000.5, 30003.5, 48556.5],
#  '77772b2d': [48504.5, 49292.0],
#  '5fda6910': [5000.5, 49291.5],
#  '33bef715': [5011.5],
#  'e681c195': [45004.0, 45002.5],
#  'e4ad71f8': [5001.5],
#  '13814d19': [48513.0],
#  '21e0c0c1': [35000.5],
#  'c0f8b9d1': [10013.0],
#  '0913de7c': [48504.5],
#  'c1008c4f': [5001.0],
#  'a6912027': [49556.0],
#  'e55aff44': [30002.0],
#  'c4270e04': [10032.5],
#  '7f41e66c': [5012.0, 49291.5, 15016.0, 40047.0],
#  'e9112c41': [5002.0, 49291.5, 49292.0],
#  '0e7f3186': [48556.5,
#   40046.5,
#   10003.0,
#   49427.5,
#   5027.0,
#   48513.0,
#   10013.0,
#   5000.5,
#   45001.5,
#   10022.5,
#   5001.0,
#   35000.5],
#  'b895b0b7': [5027.0],
#  'c42a5ef7': [45004.0,
#   10013.0,
#   5000.5,
#   49291.5,
#   49356.0,
#   5009.0,
#   5001.0,
#   30027.0,
#   40017.5,
#   35078.5,
#   30008.0,
#   5027.5],
#  'aa3be34a': [35075.5,
#   5012.0,
#   35076.0,
#   5001.0,
#   40021.5,
#   35077.5,
#   49292.0,
#   5002.0,
#   10004.0,
#   40019.0],
#  '45bf401c': [45004.0, 35000.5, 48504.5, 25003.0],
#  '11ef9491': [49291.5, 10013.0],
#  '907817b3': [49292.0, 5023.0, 45004.0, 45001.0, 5001.5],
#  '797db2d3': [5000.5, 45002.5, 10015.0, 49427.5, 45004.0],
#  '55af6fe2': [49292.0],
#  '129a6c24': [45004.0, 35018.0],
#  'b773afd8': [5000.5],
#  'c1b2c129': [10013.0],
#  '39cad568': [5025.0, 35097.0, 49292.0, 45000.5, 35096.5],
#  '6b01f734': [5009.0],
#  '83dc85ad': [30002.0],
#  '95cde76e': [45004.0],
#  '19bebbdc': [49129.5, 35013.5, 45001.5],
#  '201919d3': [40046.0],
#  '5befb751': [5011.5],
#  '1eafa53b': [35001.0],
#  'f09109ff': [40029.0],
#  '7caf712d': [49129.0, 35013.5],
#  '90b1b161': [10015.5, 45004.0, 45001.0],
#  'bcf209aa': [49291.5],
#  '8d025160': [49291.5],
#  'a68e7c9b': [10013.0,
#   5012.0,
#   45001.5,
#   5017.0,
#   49291.5,
#   5001.0,
#   49292.0,
#   5002.0,
#   10032.5,
#   48513.0],
#  'e1cbcc83': [5027.0],
#  'd295960d': [49292.0, 5000.5],
#  '3e0e1e21': [10003.0],
#  '87c2497a': [49291.5],
#  '10244856': [10003.0, 45004.0, 45001.0, 5009.0],
#  'ca20123e': [49292.0],
#  'b50896f1': [49356.0],
#  '33442c33': [10003.0,
#   48504.5,
#   5011.5,
#   45004.0,
#   48513.0,
#   45001.0,
#   49567.5,
#   49291.5,
#   5009.0,
#   5017.0,
#   40009.5,
#   48523.5,
#   10023.5,
#   10015.0,
#   49292.0],
#  'bedecec3': [5011.5,
#   40019.0,
#   48513.0,
#   5012.0,
#   45001.0,
#   5000.5,
#   49567.5,
#   35076.0,
#   49291.5,
#   49356.0,
#   5009.0,
#   40017.5,
#   49556.0,
#   35106.0,
#   49292.0,
#   48504.5,
#   5027.5,
#   25003.0],
#  'f4a801f0': [49291.5],
#  '5cd9c65c': [30027.0, 5011.5],
#  '14d0e6d9': [49291.5],
#  'c1d852d7': [49291.5],
#  '9d62ea57': [35078.0,
#   40019.0,
#   45000.5,
#   35075.5,
#   5012.0,
#   40028.5,
#   5000.5,
#   35076.0,
#   30014.5,
#   45001.0,
#   40029.5,
#   49291.5,
#   5001.5,
#   49292.0,
#   5002.0],
#  '36c55aca': [15016.0],
#  '592a57b8': [45004.5,
#   45004.0,
#   10013.0,
#   5000.5,
#   5004.5,
#   30002.0,
#   49291.5,
#   30003.5,
#   49292.0,
#   10023.0,
#   10032.5,
#   48504.5,
#   30008.5,
#   25003.5,
#   48513.0],
#  '95041e1f': [45001.0,
#   5000.5,
#   49291.5,
#   49356.0,
#   5009.0,
#   30003.5,
#   40030.0,
#   49292.0,
#   25003.0,
#   10004.0,
#   48513.0,
#   45000.5,
#   10013.0,
#   5012.0],
#  'f676c994': [49292.0],
#  'feef8707': [35005.0],
#  '4a72dd3e': [45004.0, 10032.5, 48504.5, 45000.5],
#  'b493d7da': [48523.5, 49425.0],
#  '379b26ac': [49292.0, 49291.5, 30027.0],
#  'c33b52b6': [48504.5,
#   49427.5,
#   5027.5,
#   5027.0,
#   5011.5,
#   48513.0,
#   45004.0,
#   5012.0,
#   5000.5,
#   5009.0,
#   15003.0,
#   49291.5,
#   48523.5,
#   35004.5,
#   49556.0,
#   10023.0,
#   10015.0,
#   49292.0],
#  '05622cbd': [5001.5, 49292.0, 10004.0, 45001.0],
#  '6574e9cb': [49292.0, 35096.5, 35076.0, 35076.5, 40017.5],
#  '56001458': [49292.0],
#  '864b34f8': [35006.0, 30027.0],
#  '90ce7e8b': [35078.5, 25003.5, 45001.0, 35096.5, 49129.5, 45002.5, 49292.0],
#  'e40bf2c3': [35005.0],
#  '437e95d2': [5011.5, 49292.0],
#  '96cb75ce': [49291.5],
#  '32270891': [5005.0,
#   5009.0,
#   49292.0,
#   5002.0,
#   5000.5,
#   49567.5,
#   49356.0,
#   49291.5],
#  'efbec276': [48513.0,
#   45004.5,
#   45004.0,
#   35018.0,
#   10033.0,
#   10013.0,
#   5000.5,
#   5004.5,
#   30014.0,
#   49356.0,
#   49291.5,
#   40046.0,
#   49292.0,
#   35106.0,
#   5002.0,
#   48504.5,
#   25003.0,
#   10024.0,
#   5011.5,
#   40019.5],
#  'e532a853': [10015.0],
#  '9ec40c8f': [10032.5],
#  'adcff78d': [5017.0, 5011.5, 15005.5, 5000.5, 49291.5],
#  'bd097d56': [49567.5, 10015.0, 5002.0, 25003.0, 48513.0, 10013.0],
#  'd8e5a0a7': [10013.0],
#  '25b00d36': [40020.5],
#  'f6ff4292': [5012.0],
#  'f0fca618': [49291.5],
#  '20f12385': [5000.5, 49291.5, 35097.0, 10013.0],
#  '0044b31f': [35077.0],
#  '486a0394': [49291.5],
#  'b61e69ec': [49292.0],
#  '8535418c': [45004.0],
#  '002d9fc7': [10015.0, 35000.5],
#  '4df86941': [45004.0, 5000.5, 35077.0, 49556.0, 49292.0, 25003.0],
#  'd939f446': [5001.0],
#  'af2cabfb': [15016.5],
#  'f71b4cb5': [5009.0],
#  'cecd1701': [49292.0, 40059.5, 25003.0, 5000.5, 49291.5, 10002.0, 10023.0],
#  'a207c2a1': [40009.5],
#  '6bb8da68': [5017.0, 49291.5, 49292.0, 25003.0, 45004.0, 10013.0, 45001.5],
#  '9ea646ca': [5000.5],
#  'd6cef687': [45002.5],
#  'f8208036': [20007.0, 15016.0, 10000.5],
#  '37458174': [15010.5, 5000.5, 49356.0, 45004.0],
#  '305751bf': [49292.0],
#  '3bf968c6': [49291.5],
#  '30362c22': [35005.5, 5009.0, 5001.0, 49292.0],
#  'ab331795': [40030.0],
#  '81a4cfa2': [10003.0, 5025.0],
#  '6dee53bc': [5000.5],
#  '5e5a7b9b': [10003.0, 35088.0, 5009.0],
#  '047fc6e5': [35106.0],
#  '99df67e5': [48513.0],
#  'eaa50715': [30014.0, 49291.5, 30027.0, 45003.0, 30008.0, 35005.5, 35005.0],
#  '1d8823aa': [5004.5],
#  'f789e0fe': [25003.5],
#  'b136b5ba': [48513.0],
#  '52c99f69': [49292.0, 45000.5, 49291.5],
#  '249d0031': [45001.5, 5011.5],
#  'c7b0a2ef': [5025.0],
#  '96d2bc75': [5000.5],
#  '4743599b': [25003.0],
#  '5f75a0d1': [10015.0, 35000.5],
#  '54938aae': [45001.0],
#  'd244e674': [10013.0],
#  'f67aabd9': [10023.5,
#   45003.5,
#   5027.0,
#   5011.5,
#   35018.5,
#   5000.5,
#   49291.5,
#   5001.0,
#   30003.5,
#   35000.5,
#   10015.0,
#   49292.0],
#  '6606687a': [45004.5,
#   45004.0,
#   48550.0,
#   40028.5,
#   5000.5,
#   45001.5,
#   49291.5,
#   40009.5,
#   30003.5,
#   35000.5,
#   49556.0,
#   10003.5,
#   48556.5,
#   35078.5,
#   10004.0,
#   5011.5],
#  'f0fa31ea': [49567.5, 45004.5],
#  '36bbadab': [45001.0],
#  '07f25815': [25003.0, 30009.0, 5000.5, 49356.0],
#  '1eea7ec5': [10023.5, 10032.5, 35005.0, 45004.0, 48513.0, 49291.5],
#  'f49a57d2': [5017.0,
#   49291.5,
#   5009.0,
#   49556.0,
#   49292.0,
#   10023.0,
#   40030.5,
#   49427.5,
#   25003.5,
#   25003.0,
#   48513.0,
#   5000.5,
#   40069.5,
#   45001.0],
#  '9906ffcc': [15004.0],
#  'f2ad2ecb': [45004.0, 40072.5, 5000.5, 35076.0, 49292.0, 25003.5],
#  '115d3220': [35087.5, 60050.5],
#  '239e62aa': [5009.0],
#  '2617e510': [10015.0],
#  '515b0fc7': [10032.5],
#  'c6695235': [48523.5,
#   5002.0,
#   10004.0,
#   5000.5,
#   35096.5,
#   45001.0,
#   30002.0,
#   5009.0],
#  'e5a77767': [45004.0],
#  '6702d960': [35000.5],
#  '3a28eef2': [48556.5],
#  'a37e817c': [5000.5,
#   30014.5,
#   45001.0,
#   49291.5,
#   5001.0,
#   49292.0,
#   10023.0,
#   5002.0,
#   35005.5,
#   10032.5,
#   25003.0,
#   48513.0,
#   15002.0],
#  '2488544f': [45003.0],
#  '91a93e09': [49291.5],
#  '9fd21c47': [45000.5],
#  'ab809370': [45004.0],
#  'fb695c2b': [5000.5],
#  '4f72744c': [5002.0],
#  '691498bc': [49291.5, 35106.0],
#  'dcfbe542': [49291.5, 45004.0],
#  '33c54145': [10015.0, 48504.5, 25003.0, 48513.0, 10013.0, 49291.5],
#  '182a0e4a': [10023.0,
#   10032.5,
#   49427.5,
#   25003.0,
#   30021.5,
#   45004.0,
#   5000.5,
#   10022.5,
#   5001.0,
#   30003.0,
#   49292.0],
#  '24b20f69': [25003.0, 40028.5, 35076.0],
#  'de146d2b': [49292.0],
#  '122f5c59': [49556.0,
#   45002.5,
#   40009.5,
#   40046.0,
#   35000.5,
#   10015.0,
#   49292.0,
#   48504.5,
#   49452.0,
#   45004.0,
#   48513.0,
#   45000.5,
#   5012.0,
#   45001.5,
#   35076.0,
#   49291.5,
#   49356.0,
#   48523.5,
#   40021.5],
#  'dac69993': [10013.0,
#   5017.0,
#   5009.0,
#   5001.5,
#   30003.0,
#   49292.0,
#   10023.0,
#   35005.5,
#   25003.0,
#   10024.0,
#   10032.5,
#   48504.5,
#   5011.5,
#   45004.5],
#  '4400fbd5': [49356.0, 10004.0],
#  'a13466e2': [10023.0],
#  '31c2277c': [10013.0],
#  '4b5afc8a': [40030.0, 48504.5, 10013.0],
#  '69f8df49': [25003.0, 20024.5],
#  '6a5a0a74': [5011.5],
#  'e93d6694': [45004.0],
#  'de2d189e': [45004.0],
#  '2026d529': [35005.5],
#  '015deddd': [5009.0, 35106.0, 49292.0],
#  'c7330698': [49291.5],
#  '41891b0b': [49291.5],
#  '282e6d36': [49414.0],
#  '5f6c59f7': [35018.0, 40009.5],
#  '50724b9d': [49291.5,
#   35097.0,
#   10031.0,
#   49556.0,
#   49292.0,
#   25003.5,
#   10004.0,
#   30009.5,
#   10013.0],
#  '1ad325f5': [49291.5,
#   5001.5,
#   5001.0,
#   5005.0,
#   5009.0,
#   45002.5,
#   49292.0,
#   10003.5,
#   35106.0,
#   5027.0,
#   25003.0,
#   10024.0,
#   5011.5,
#   48513.0,
#   10021.0,
#   5000.5,
#   35076.0,
#   45001.5],
#  'b325013b': [45003.0],
#  '762d3ff3': [10013.0,
#   5000.5,
#   45001.5,
#   40021.5,
#   49292.0,
#   10032.5,
#   45004.0,
#   48513.0],
#  'e48a2c02': [10013.0],
#  'c638973a': [49265.5, 40021.5],
#  '36a0e65d': [49291.5],
#  '0dca20a5': [49356.0],
#  'd0ba5e42': [49291.5, 5009.0, 10023.5, 48504.5, 45001.0, 45001.5],
#  '0d521b77': [40019.5],
#  '31da6421': [35005.5],
#  '7839e3af': [35075.5, 35076.0],
#  '30bd535e': [10015.0,
#   35075.5,
#   5000.5,
#   49567.5,
#   35076.0,
#   10022.5,
#   49291.5,
#   35077.5],
#  'de5afdf7': [10004.0, 30027.0],
#  'f49fd788': [5002.0, 25003.0, 35075.5, 5001.5, 35000.5, 49292.0],
#  'f5dfee50': [45003.5],
#  '3a38b0fc': [49291.5],
#  '21f6b0d8': [48504.5, 40021.5],
#  '2ce52ff4': [40002.5, 40043.0],
#  '2aa0ea6a': [35075.5, 5002.0],
#  '2a451589': [40046.0, 40059.5, 5000.5, 40054.0],
#  'a56ee179': [49292.0, 35076.0],
#  '5469a86f': [10013.0],
#  '44a6dcf6': [5025.0, 35005.5, 48555.0],
#  'ce5b212c': [49130.0, 30021.5, 5000.5],
#  'dbd8102a': [35001.0, 49356.0],
#  'cb046436': [49129.0],
#  '4c660a98': [49291.5, 48504.5],
#  'd7e59279': [45004.0, 30014.0, 35000.5, 35005.0, 25003.0],
#  'e1e1354a': [49291.5],
#  '439bd52a': [30021.5],
#  'a759af21': [5000.5],
#  '4798fa50': [5017.0],
#  '9957d9e8': [45001.0, 5001.0, 10032.5],
#  '4c80d33c': [5002.0, 5000.5],
#  'fc99f0ad': [35096.5],
#  'c63738b1': [45004.0, 5009.0],
#  '6fb044c6': [40027.5, 49356.0],
#  '94a79298': [49292.0],
#  '562d401a': [49291.5, 48513.0],
#  '2ad4985b': [40009.5],
#  '51f2fdde': [40002.5],
#  '3427b5c5': [5017.5, 45004.0],
#  '11880b6f': [49292.0],
#  'dd754ff3': [45001.5, 49291.5, 40021.5, 49292.0, 48504.5, 5000.5],
#  '746fed8f': [5012.0],
#  'ce8ec668': [40030.0],
#  'da66f34f': [49129.0],
#  '79a4d868': [49427.5],
#  'e1e1ae41': [10015.0,
#   49292.0,
#   10003.0,
#   45004.0,
#   30029.0,
#   10013.0,
#   5000.5,
#   5001.0,
#   5001.5,
#   49556.0,
#   15016.5,
#   10023.5,
#   10023.0],
#  '9e1eb350': [5027.0],
#  '9d8939c0': [49556.0, 10024.0, 5000.5, 49291.5],
#  '407faa84': [49292.0, 35077.5],
#  'c2dc67a5': [48523.5,
#   35000.5,
#   15004.0,
#   10024.0,
#   35001.0,
#   35076.0,
#   35105.5,
#   40009.5],
#  'd0dc89c0': [10015.0,
#   49292.0,
#   10023.5,
#   10032.5,
#   48504.5,
#   5023.0,
#   25003.0,
#   5011.5,
#   45004.0,
#   30009.0,
#   15002.0,
#   45001.0,
#   45001.5,
#   5000.5,
#   49567.5,
#   5025.0,
#   49356.0,
#   49291.5,
#   5009.0],
#  'd37313ef': [49567.5, 49291.5, 49292.0],
#  '97c574e7': [35076.0, 49292.0, 35006.5],
#  '04393d06': [5009.0, 40009.5, 48523.5, 5000.5, 45001.5, 30002.0],
#  '32ab062c': [40019.5,
#   5012.0,
#   45001.5,
#   5000.5,
#   40073.0,
#   10022.5,
#   5001.0,
#   49556.0,
#   10023.0,
#   40009.5,
#   49292.0,
#   15016.0,
#   40030.0,
#   5002.0,
#   49427.5,
#   25003.5,
#   5011.5],
#  'ff8e6b50': [5009.0],
#  '6886144a': [5000.5],
#  'b8adde6f': [49292.0],
#  '6d945df2': [49292.0, 5000.5],
#  'dc4063ba': [49291.5, 48523.5, 49130.0, 35076.0],
#  'afe0fb57': [10003.0, 10033.0],
#  '2427df36': [5000.5],
#  'c6442b32': [49292.0, 45001.0],
#  '076926ac': [49292.0],
#  'bbb9830f': [49292.0],
#  '99aa8a66': [45004.0, 49292.0],
#  '1b669b6b': [49291.5],
#  '4fdd5ff4': [40021.5],
#  'd4a4310c': [49129.0],
#  '263cb765': [5011.5],
#  '91af9aea': [5000.5, 49291.5, 40019.0],
#  'e359304c': [5000.5],
#  '47a9a0d0': [49291.5],
#  'db53daaa': [49292.0],
#  '0a103436': [5009.0],
#  '4353aef3': [49291.5],
#  '6876e03f': [49292.0],
#  '9b9cb524': [49567.5],
#  'ae5f07e4': [45001.0,
#   49291.5,
#   10015.0,
#   49292.0,
#   15016.5,
#   10003.0,
#   5027.0,
#   25003.5,
#   10013.0,
#   10001.0,
#   5000.5],
#  '91bd51a8': [40028.5],
#  'd6f0e219': [49291.5],
#  'b6f3c4dc': [30029.5],
#  '8887189b': [35000.5, 35096.5],
#  '7db66b41': [35005.5, 49291.5],
#  'ac5d4e17': [48556.5],
#  'd833913a': [5000.5,
#   5009.0,
#   10015.0,
#   10023.0,
#   20034.5,
#   49427.5,
#   25003.5,
#   5011.5,
#   45004.0],
#  '238e95b2': [45001.5,
#   5000.5,
#   5001.0,
#   5001.5,
#   5009.0,
#   10023.5,
#   10015.0,
#   5002.0,
#   10032.5,
#   5027.0,
#   25003.5,
#   45004.0],
#  'd7492db7': [49292.0],
#  '66a6de06': [40069.5, 45004.0, 30009.0],
#  '3f3b6b69': [49556.0],
#  'ec848481': [49292.0, 45013.5],
#  'ecf21902': [48513.0,
#   45000.5,
#   5000.5,
#   5009.0,
#   35105.5,
#   5017.0,
#   49556.0,
#   40009.5,
#   48556.5,
#   10015.0,
#   49292.0,
#   10003.0,
#   25003.0,
#   25003.5,
#   45004.0],
#  'df0daf49': [40030.0, 49292.0, 60048.5, 35076.0],
#  '36d40cf1': [25003.0, 30009.0],
#  'a800153a': [49292.0],
#  '435cf9f7': [48513.0,
#   45004.0,
#   40068.0,
#   49291.5,
#   5009.0,
#   10015.0,
#   49292.0,
#   48504.5],
#  '1af631c1': [49291.5],
#  '815596a0': [35005.5, 35005.0, 35076.0, 49292.0, 35078.5],
#  '332ac6d1': [45003.5],
#  '457bb048': [49291.5,
#   10022.5,
#   49356.0,
#   5017.0,
#   5001.5,
#   49292.0,
#   5002.0,
#   10003.0,
#   25003.5,
#   25003.0,
#   45000.5,
#   10013.0,
#   45001.0,
#   5000.5],
#  '895b20c2': [49567.5, 10022.5, 5001.0, 5000.5],
#  '9f999b4e': [49292.0],
#  'e8bf159a': [49292.0],
#  'ea769506': [49291.5, 45004.0, 45001.0],
#  '3746eba3': [5009.0],
#  '3aa8e748': [10013.0,
#   5000.5,
#   5012.0,
#   45001.0,
#   49291.5,
#   5001.5,
#   40009.5,
#   10023.5,
#   49292.0,
#   5027.5],
#  '5ab79993': [45003.0, 49292.0],
#  'eca33552': [35000.5],
#  '7d412398': [30009.0, 30026.5, 49356.0, 40009.5, 10004.0, 5011.5, 45000.5],
#  '4112b383': [40021.5,
#   35000.5,
#   49292.0,
#   15016.5,
#   49427.5,
#   25003.0,
#   5011.5,
#   45000.5,
#   45004.0,
#   10013.0,
#   5000.5,
#   49567.5,
#   45001.5,
#   45001.0,
#   35105.5,
#   49291.5,
#   5009.0],
#  'd55d0898': [45004.0],
#  '9137f7c3': [49291.5],
#  '84136d60': [5009.0,
#   5017.0,
#   10015.0,
#   5002.0,
#   10032.5,
#   5027.0,
#   5011.5,
#   35006.0,
#   45000.5,
#   45004.0],
#  '2ee2eb78': [5011.5, 35018.0, 5012.0, 45001.0, 49291.5, 40045.5, 5001.0],
#  'ca5519d1': [49291.5, 48523.5, 45004.0],
#  '19f3a7d2': [49291.5],
#  '71c42024': [35000.5],
#  '261dcfa8': [40020.5],
#  'e666e2e6': [45001.0, 30027.0],
#  '8235d5f8': [35001.0, 40069.5],
#  'de45e522': [49292.0, 49556.0],
#  'a1d49d65': [5011.5],
#  '1d91da46': [10015.5, 10013.0],
#  'e8afb2b4': [10003.0, 30021.5, 45004.0, 45001.0],
#  '1eee50da': [15016.5],
#  '7f8f22ec': [49427.5],
#  'da36fcdd': [200002.0,
#   15002.0,
#   10013.0,
#   5000.5,
#   45013.5,
#   10015.0,
#   10003.0,
#   15005.0,
#   5027.0,
#   48513.0],
#  '87fa22a4': [45001.0, 5009.0],
#  '317c50b0': [10013.0, 45001.5, 45004.0],
#  '021be877': [15004.0],
#  'b841c63d': [49292.0, 10023.5, 15008.5, 49427.5, 25003.0, 45001.0],
#  'ccbad87e': [49556.0],
#  '5b2ce1df': [10002.0,
#   5009.0,
#   10006.0,
#   35077.0,
#   15016.5,
#   15016.0,
#   10003.0,
#   30021.5,
#   5012.0,
#   5000.5,
#   10022.5],
#  'a95cdcf7': [48504.5, 49291.5, 49356.0, 49556.0],
#  'dab15626': [49556.0],
#  '51ed1ef9': [45004.0, 49292.0],
#  '42537f4b': [5009.0],
#  'bfe90390': [35096.5],
#  '0870a959': [45004.0],
#  '6bc64e8c': [40009.5, 49291.5],
#  '9c9341f8': [10023.0],
#  '0a16ebe8': [5000.5, 5009.0, 10023.0, 48556.5, 5002.0, 45004.0, 25004.0],
#  '1e9007a5': [49427.5, 25004.0, 49356.0, 49291.5],
#  'a1dc1b69': [49292.0, 10022.5],
#  'e5457503': [40020.5],
#  '070daae1': [35004.5],
#  '137f1c8d': [45004.0],
#  'e63f7dc7': [40021.5],
#  'f535ad0a': [49292.0, 5000.5],
#  'a03dd8af': [40021.5],
#  '248ae354': [35076.0],
#  'a297fd77': [45004.0],
#  'c9365a50': [49292.0],
#  '3e091e4e': [49292.0],
#  'd6518fa1': [49292.0, 10032.5, 5011.5, 5000.5, 49291.5],
#  '35223d4c': [49291.5],
#  '3a16d31f': [40009.5,
#   40017.5,
#   5002.0,
#   40002.0,
#   15001.5,
#   35071.5,
#   10033.0,
#   10013.0,
#   35096.5],
#  '17b8ceb2': [45004.0, 5000.5],
#  '77191f64': [5001.5],
#  '4e96001f': [10015.0,
#   10003.0,
#   45003.5,
#   10032.5,
#   25003.0,
#   5011.5,
#   5015.0,
#   5012.0,
#   5000.5,
#   45001.5,
#   49291.5,
#   10022.5,
#   5009.0,
#   15003.0,
#   45002.5],
#  '5f44a418': [165017.0],
#  '42a511fd': [49567.5],
#  'a2bd9c1d': [5001.0, 5009.0, 49292.0, 5002.0],
#  'af0d4678': [10003.0, 45004.0, 45001.5, 40069.5, 48556.5, 10015.0, 49292.0],
#  'f8ef7e01': [49292.0],
#  '55d6b94c': [10013.0],
#  '3d928f6c': [45004.0],
#  '5c92d0d8': [5000.5,
#   30014.0,
#   10022.5,
#   49291.5,
#   5009.0,
#   49556.0,
#   49292.0,
#   15016.5,
#   48513.0,
#   30009.5,
#   40036.0],
#  '30d2ebaa': [49292.0],
#  'd76088e7': [35075.5, 35106.0, 48504.5],
#  'dd5f584a': [10013.0],
#  'fdb455b8': [35001.0],
#  '24928342': [40009.5],
#  '3bf82927': [5000.5,
#   5009.0,
#   49556.0,
#   45002.5,
#   30003.0,
#   49292.0,
#   10003.0,
#   40075.5,
#   25003.5,
#   10024.0],
#  'b5aa77b7': [48556.5, 48513.0, 49556.0],
#  'bb29fcdb': [40027.0],
#  'cd1ee9f6': [5000.5, 5009.0],
#  '99ba7061': [5000.5, 5002.0],
#  '29258f66': [5002.0,
#   10032.5,
#   48504.5,
#   25003.5,
#   5011.5,
#   48513.0,
#   5000.5,
#   49291.5,
#   5001.0],
#  'f80d714c': [48504.5, 35001.0, 5012.0, 49291.5],
#  '8709a0e8': [35076.0, 49292.0],
#  '25d79a83': [40027.5, 35018.5, 49292.0],
#  'dca84691': [45004.0],
#  'fe930eb2': [48504.5, 49356.0, 49556.0, 49292.0],
#  '436b0eaa': [49292.0],
#  'a7689ff5': [35106.0],
#  '4205ce27': [48556.5,
#   40030.0,
#   49292.0,
#   5002.0,
#   10003.0,
#   10032.5,
#   48504.5,
#   25003.0,
#   10024.0,
#   5011.5,
#   45004.0,
#   30009.0,
#   5000.5,
#   35011.5,
#   45001.0,
#   49567.5,
#   49356.0,
#   10023.0],
#  '23487c91': [5007.0,
#   45001.0,
#   10022.5,
#   49356.0,
#   5017.0,
#   49291.5,
#   49556.0,
#   49292.0,
#   10032.5,
#   15009.5],
#  '9fd1f2ab': [45004.0],
#  '0b7bfa75': [40075.0, 5000.5, 10022.5, 40021.5],
#  'c33add88': [5000.5],
#  '7e5e8f08': [5000.5, 45001.0, 48556.5, 45004.0, 10013.0],
#  'dad21636': [48504.5, 5000.5, 45001.5],
#  'cb3d5684': [5000.5,
#   49291.5,
#   30027.0,
#   49556.0,
#   48511.0,
#   48504.5,
#   49427.5,
#   5027.0,
#   25003.0,
#   10013.0],
#  '7fc23936': [35004.5],
#  '0adba3e2': [49567.5],
#  'd458afe0': [30002.0, 45004.0, 48513.0],
#  '8d81cd7d': [60048.5, 35096.5, 35104.0, 10022.5, 10023.0],
#  '3fe42f90': [45004.0],
#  '520e2712': [5009.0],
#  'b461b218': [40009.5],
#  'ee1b8f44': [5000.5],
#  '1dca451b': [45004.0, 49291.5],
#  '32cd3eff': [60049.0],
#  'c74988fc': [48513.0],
#  '662a14e7': [45004.0, 5017.0, 5025.0, 5005.0, 25003.5, 25003.0, 5011.5],
#  'f3561933': [49291.5],
#  '8661c6f5': [30009.0],
#  'b1a64c02': [49291.5, 35005.5],
#  '9f8c22ad': [35018.5],
#  '02c0b6f5': [30002.0],
#  'd4112fd8': [49292.0],
#  '06a1bb03': [49129.5, 49291.5],
#  '69f19e3c': [5000.5, 35076.0, 49291.5, 10004.0],
#  '3aacc43f': [5012.0],
#  'ca0ff8ae': [35096.5],
#  '1de724b6': [49292.0],
#  '0c291e3e': [5027.0],
#  '18f62405': [49292.0],
#  '7a80f9bd': [10015.0],
#  '9268e2bf': [5000.5],
#  'd553730b': [48550.0],
#  'd64c9a94': [35076.0, 5017.0, 35075.5, 30009.0],
#  '4190aa52': [48513.0, 49291.5],
#  '11831a58': [49291.5],
#  '25001235': [5003.0, 5000.5, 35076.0, 5009.0],
#  '21036467': [30029.5],
#  '755831d5': [5017.0],
#  '1c02e3f1': [40045.5, 35000.5, 40002.0, 35018.5],
#  '469854d5': [45001.0, 48556.5],
#  'dd49f6f0': [48504.5],
#  '99b74df2': [10015.0, 35078.0, 49129.0],
#  'e5d3bd21': [49292.0],
#  '15a63eb7': [5025.0, 5002.0],
#  '87ea4afe': [5000.5],
#  '54336aac': [5002.0],
#  '04ae83eb': [30002.0],
#  '212e7e2c': [49291.5, 49130.0],
#  '25a52073': [5000.5],
#  '08d4ab12': [30009.0],
#  '85e8e7a4': [49292.0, 35005.5, 40043.0, 35077.0],
#  'd260e294': [45000.5],
#  '6a72d9a2': [49556.0, 49292.0, 35005.5],
#  'f40125b0': [5000.5],
#  '28fabe48': [40028.5],
#  '38b0c72c': [40045.5],
#  '714b5255': [40009.5, 45004.0, 35076.0],
#  '51c38ca9': [49291.5],
#  '941c0463': [40021.5],
#  '2c0a7d7d': [10013.0, 30002.0, 10015.0, 5012.0],
#  '39c19c8a': [25003.0,
#   5011.5,
#   5012.0,
#   5000.5,
#   30014.0,
#   5017.0,
#   49291.5,
#   5009.0,
#   30003.5,
#   10015.0,
#   10003.0,
#   10032.5],
#  'ad1f5b8e': [49291.5, 45004.0],
#  '5c495449': [5000.5, 48504.5, 45004.0],
#  '3f4e4090': [49291.5, 30009.0, 5000.5],
#  'ce157b1c': [48504.5],
#  '17c948b7': [10032.5],
#  '8d683db5': [49291.5,
#   10022.5,
#   40009.5,
#   40054.5,
#   49292.0,
#   40002.5,
#   45004.0,
#   30009.5,
#   5000.5],
#  '19fde25c': [45004.0, 45001.0, 49427.5, 48504.5],
#  '1acadd65': [10013.0, 5004.5, 5012.0],
#  '76a1d7c1': [49291.5, 49292.0, 5027.5],
#  'a7ba1580': [10003.0],
#  '65099c5f': [49356.0],
#  'e4ca5a6d': [5002.0],
#  '820863c7': [5012.0],
#  'd28c61d7': [45004.0, 45001.5, 25003.0],
#  '5c0e5c72': [49291.5, 10004.0, 10013.0, 35076.0],
#  '85892777': [49292.0],
#  '88f5087f': [5000.5],
#  '6c55bf20': [30009.5],
#  '6b415c0e': [49356.0],
#  '38262091': [45004.0],
#  '0db47920': [49291.5],
#  'e6a1920c': [5009.0],
#  'd18505f3': [49291.5, 49292.0, 10023.0, 48504.5, 45004.0, 49356.0],
#  '58778632': [5003.0],
#  'e78138da': [40003.0, 40002.0],
#  'd80ed7fb': [48584.0],
#  'a890dda7': [10013.0],
#  '40eedddc': [40027.0],
#  '3c247f6e': [30003.5, 10003.5, 49427.5, 10004.0, 5011.5],
#  '593dda1d': [49356.0],
#  '5ca10c9f': [5009.0,
#   49292.0,
#   48556.5,
#   10015.0,
#   5002.0,
#   49427.5,
#   10032.5,
#   10004.0,
#   45004.0,
#   48513.0,
#   49356.0,
#   49291.5,
#   5025.0,
#   10022.5],
#  'dd2a9146': [49414.0, 48504.5],
#  '23557b10': [45004.0, 45000.5, 10013.0, 5000.5],
#  'ab4c02d9': [48513.0,
#   45001.0,
#   45001.5,
#   5000.5,
#   20024.5,
#   10022.5,
#   5017.0,
#   30027.0,
#   49556.0,
#   49292.0,
#   10023.5,
#   10003.0,
#   10032.5,
#   48504.5,
#   5027.0,
#   25003.5,
#   25003.0],
#  'd2aa4410': [5012.0,
#   5000.5,
#   48523.5,
#   49556.0,
#   45002.5,
#   10023.0,
#   48556.5,
#   5002.0,
#   5004.5],
#  '5dd01ad0': [49556.0],
#  'd38f9b82': [49427.5],
#  '022cbfa0': [10003.0],
#  'a2c36d8f': [5001.0],
#  '4d1b506c': [48513.0],
#  '2f73fc54': [49291.5, 45004.0],
#  '984729fc': [40036.0],
#  'f7466f45': [5009.0, 35020.0],
#  '7d0e7f38': [10004.0, 49292.0],
#  '14efcfdb': [45001.5],
#  'a1073595': [30003.0],
#  'd2f44cf6': [49356.0],
#  'f88b3ded': [5000.5],
#  '4f88ad3b': [10022.5],
#  '0aa1981d': [48556.5, 40020.5],
#  '34acc7cf': [45001.5, 5009.0, 10023.0, 5011.5],
#  '1a930ed4': [10001.0, 10000.5, 48513.0, 45004.0],
#  '0e3d6d1d': [40069.5],
#  'b86e050b': [45004.0, 35077.0],
#  '539b24d3': [45004.0],
#  '87b67140': [45004.0],
#  'e9fdbbd6': [49130.0, 30009.5, 5000.5, 45001.0, 5009.0],
#  'a376c5ef': [49291.5, 49292.0, 5000.5],
#  'c45ea0da': [25003.0],
#  'c7024274': [49292.0,
#   5002.0,
#   49130.0,
#   48504.5,
#   45004.0,
#   10013.0,
#   35096.5,
#   49556.0],
#  '2d8cceb5': [5000.5],
#  '3982c8fa': [10022.5, 49292.0],
#  '362bb783': [49291.5],
#  '6e0ce92b': [10023.0],
#  '078ec829': [10022.5],
#  '5780387f': [45004.0],
#  '7526dad9': [10015.0,
#   5000.5,
#   49567.5,
#   5025.0,
#   10022.5,
#   49291.5,
#   5001.0,
#   5009.0],
#  '959d71f1': [40002.0],
#  'c0c8dc3a': [5012.0,
#   5000.5,
#   49291.5,
#   48523.5,
#   30003.5,
#   49292.0,
#   45003.5,
#   48504.5,
#   40002.0,
#   5027.0,
#   48513.0,
#   45004.0,
#   10013.0],
#  'cc557060': [35000.5, 30003.5, 5011.5, 30002.0, 5009.0],
#  'd6041623': [49291.5, 10013.0],
#  'd1ee5f48': [10023.5, 25003.0, 49567.5, 5001.0, 49292.0],
#  '393250b2': [30027.0, 40036.0],
#  '56767b45': [5027.0],
#  'e705e811': [48504.5],
#  '4bdcd155': [45001.5],
#  'bebb6e71': [49291.5],
#  'e8244bb5': [49292.0],
#  'f94f87f4': [49292.0, 5000.5, 45001.0],
#  'cfa8430e': [40030.0],
#  'c903f221': [49292.0, 40017.5, 35000.5],
#  '18939778': [25003.0, 45001.0, 5000.5, 30002.0, 49292.0],
#  '2c2b20e8': [49292.0, 40072.0],
#  '4d9c5506': [49356.0,
#   49291.5,
#   40009.5,
#   30027.0,
#   49292.0,
#   5027.5,
#   25003.0,
#   40027.0,
#   45004.0,
#   30009.0,
#   48513.0,
#   10013.0,
#   5000.5,
#   35076.0],
#  '7cdd5c7d': [49292.0],
#  '94cc603b': [48513.0, 45001.0],
#  '98d80076': [45001.0],
#  '736537e1': [48513.0],
#  'b431206d': [49291.5],
#  '25d3d594': [49427.5],
#  'cf1f710d': [30014.0,
#   10022.5,
#   5009.0,
#   40009.5,
#   35000.5,
#   49556.0,
#   25003.0,
#   25003.5,
#   10032.5,
#   5011.5,
#   5000.5],
#  '6710030c': [45004.0, 35000.5],
#  'eee4036e': [49291.5,
#   5001.5,
#   45000.5,
#   45004.5,
#   45004.0,
#   35075.0,
#   10013.0,
#   5000.5,
#   45001.5],
#  '1f0f102c': [5011.5],
#  '8099a346': [20007.5, 5000.5, 49556.0, 45003.0, 10032.5, 5027.0, 25003.0],
#  '1d35e178': [30014.5,
#   5009.0,
#   10023.5,
#   30003.0,
#   35000.5,
#   5002.0,
#   10024.0,
#   30021.5,
#   5012.0,
#   5000.5],
#  '98d9e481': [5000.5],
#  '8359f170': [49427.5, 25003.0, 30014.5, 35004.5],
#  '13d6ff4c': [49292.0, 35005.5, 45004.0, 49356.0, 45002.5],
#  '33ae37e6': [10022.5, 49356.0, 35000.5, 5011.5, 45004.0, 5017.0],
#  'a9640a5b': [25003.0, 30029.0, 35076.0, 5001.0, 40021.5, 48523.5],
#  '7001d8ce': [30003.0],
#  '8589456d': [30014.0, 48504.5],
#  '8f310a9f': [48513.0,
#   5012.0,
#   10013.0,
#   5000.5,
#   45002.5,
#   30027.0,
#   10023.0,
#   5027.0,
#   5011.5,
#   40027.0],
#  'c5513c3c': [5001.0],
#  'e0059a3e': [45004.0, 25003.0],
#  '0e7ae3a6': [10015.0,
#   49292.0,
#   30009.0,
#   20007.5,
#   10013.0,
#   5000.5,
#   5009.0,
#   10023.5,
#   35106.5],
#  '6c756604': [45004.0, 45004.5],
#  '7fea851b': [49292.0, 45004.0],
#  'e0890ef3': [10013.0],
#  '8d200e88': [49291.5],
#  'ab6b61d9': [5001.5],
#  '0bb486b2': [35078.5, 5011.0, 45004.0, 5012.0],
#  '3216e943': [25003.5],
#  'f8dad4b7': [10023.5],
#  '4d8b2d98': [25003.0],
#  '6bc7509f': [5012.0],
#  'a846e75e': [49292.0],
#  '8dafed52': [35005.5, 30027.0],
#  ...}

# %%
# len(Code_Product_dict)

# %%
# list(Code_Product_dict.keys())[0]

# %%
# def product_recommend(name):
#     if name in Code_Product_dict.keys():
#         index = list(Code_Product_dict).index(name)
#         print(index)
#         for j in range(len(list(Code_Product_dict.values())[index])):
#             dfr=pd.DataFrame(d.corr(method='pearson')[list(Code_Product_dict.values())[index][j]].sort_values(ascending=False).iloc[:11])
#             dfr.reset_index(inplace=True)
#             print('\n')
#             print(list(Code_Product_dict.keys())[index])
#             dfr_filtered = dfr[dfr['Code_Product'] != list(Code_Product_dict.values())[index][j]]
    
#             print(dfr_filtered)
#     else:
#         print('user does not exist')

# %% [markdown]
# code_pcoeff: empty list containing code_product and their pearson coefficients.<br> Function created to pass Main_Id as a parameter to obtain recommendation for given Main_Id(User).<br> Check initiated to accept only valid Main_Id via first If else statement.<br> First for loop:loop through each code_product for a given user and provide recommendation for each code_product<br>len(list(Code_Product_dict.values())[index]:contains length of the list of code_products against the index of Main_ID<br>dfr is dataframe containing correlation of code_products, all the NaN values are filled with zero<br> Reset_index is done to decrease the multilevel indexing<br>dfr_filtered: exclude the correlation of a code_product with itself<br> Second for loop: loop through the first two recommended code_products against each code_product purchased by Main_ID and append the corresponding code_products with their pearson cofficients in  code_pcoeff.<br>Seconf If else statement: To provide maximum of 10 recommendations to any user.<br>first_data_code_pcoeff: only extarct the code_product not the pearson coeffient.

# %%
def product_recommend(name):
    code_pcoeff=[]
    
    if name in Code_Product_dict.keys():
        index = list(Code_Product_dict).index(name)
        print(index)
        for j in range(len(list(Code_Product_dict.values())[index])):
            dfr=pd.DataFrame(d.corr(method='pearson').fillna(0)[list(Code_Product_dict.values())[index][j]].round(3).sort_values(ascending=False).iloc[:5])
            dfr.reset_index(inplace=True)
#             print('\n')
#             print(list(Code_Product_dict.keys())[index])
            dfr_filtered = dfr[dfr['Code_Product'] != list(Code_Product_dict.values())[index][j]]
            dfr_filtered.reset_index(drop=True, inplace=True)
            for i in range(2):
                cp=tuple(list(dfr_filtered.iloc[i]))
                code_pcoeff.append(cp)
    else:
        return 'user does not exist'
        
        
    if len(code_pcoeff)>10:
        code_pcoeff=code_pcoeff[slice(10)]
    else:
        code_pcoeff=code_pcoeff 
        
        
#     print(code_pcoeff)   
    first_data_code_pcoeff = [t[0] for t in code_pcoeff]   
    return 'List of items purchased by user',list(Code_Product_dict.values())[index],'List of items recommended to user', first_data_code_pcoeff

# %%
product_recommend('361e3b9f')
# Out:
# 15699
# ('List of items purchased by user',
#  [48513.0, 45001.0],
#  'List of items recommended to user',
#  [30026.5, 15002.0, 15004.0, 30009.5])

# %%
# recom_df[recom_df['Main_ID']=='361e3b9f']

# %%
# dfr=pd.DataFrame(d.corr(method='pearson').fillna(0)[48513.0].sort_values(ascending=False).iloc[:5])
# dfr.reset_index(inplace=True)

# %%
# list(set(list(Code_Product_dict.values())[12]))[0]

# %%
# recom_df[recom_df['Main_ID']=='021bfefb']

# %%
# dd=pd.DataFrame(np.diag(d2), index=[d2.index, d2.columns])
# dd

# %%
# dd[0].sum()
